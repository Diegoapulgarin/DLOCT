# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from Deep_Utils import sliding_window, inv_sliding_window
from Utils import logScaleSlices, inverseLogScaleSlices, downSampleSlices
from Metrics import ownPhaseMetricCorrected_numpy, ssimMetric, ownPhaseMetric_numpy
import os

# %%
root=r'D:\DLOCT\Cgansub_260123'
model_folder = '\\Nueva carpeta\cGAN_subsampling'
path = root+model_folder
savefolder = path
d_loss1 = np.load(path+'\d_loss1.npy')
d_loss2 = np.load(path+'\d_loss2.npy')
g_loss = np.load(path+'\g_loss.npy')
n_epochs = np.load(path+'\\n_epochs.npy')
fig,axs = plt.subplots(2,1)
axs[0].plot(d_loss1)
axs[0].plot(d_loss2)
axs[1].plot(g_loss)

# %%
""" Load tomograms"""
rootFolder = 'D:/DLOCT/TomogramsDataAcquisition/' # porcine cornea
fnameTom = 'ExperimentalTomogram/ExperimentalROI_corrected5' # porcine cornea

# rootFolder = 'D:/DLOCT/TDG/OCT_Real/nueva data/' # s.eye_swine
# fnameTom = '[p.SHARP][s.Eye2a][10-09-2019_13-14-42]_TomJones_z=(586)_x=(512)_y=(512)'# s.eye_swine

""" Shape of each tomogram, as tuples (Z, X, Y)"""

tomShape = [(350,384,384)]# porcine cornea
# tomShape = [(586,512,512)] # s.eye_swine

fname = rootFolder + fnameTom
# Names of all real and imag .bin files
fnameTomReal = [fname + '_real.bin' ]
fnameTomImag = [fname + '_imag.bin' ]
tomReal = np.fromfile(fnameTomReal[0]) # quit single for porcine cornea and put single for s_eye ,dtype='single'
tomReal = tomReal.reshape(tomShape[0], order='F')  # reshape using
# Fortran style to import according to MATLAB

tomImag = np.fromfile(fnameTomImag[0])
tomImag = tomImag.reshape(tomShape[0], order='F')  # reshape using
# Fortran style to import according to MATLAB

tomData = np.stack((tomReal, tomImag), axis=3)
# tomData = tomData/np.max(abs(tomData)) # normalize tomogram

# %%
n = 128
n1 = 128
window_size = (n,n)
stride = (n1,n1)
slices = []
zinit= int(np.round(tomShape[0][0]/2)-3)
zfinal= zinit + 6
#tomData=tomData[zinit:zfinal,:,:,:]
for b in range(6):
    i = b + zinit
    bslicei = sliding_window(tomImag[i,:,:],window_size,stride)
    bslicer = sliding_window(tomReal[i,:,:],window_size,stride)
    bslice = np.stack((bslicer,bslicei),axis=3)
    slices.append(bslice)
slices = np.array(slices)
slices = np.reshape(slices,(slices.shape[0]*slices.shape[1],slices.shape[2],slices.shape[3],slices.shape[4]))
del bslicei,bslicer,bslice
logslices, slicesMax, slicesMin = logScaleSlices(slices)
logslicesUnder = downSampleSlices(logslices)

# %%
samples = 4096
path_models = path + '\Models'
quanty_models = samples*100
path_models
models = os.listdir(path_models)

# %%
metrics = []
for i in models:
    print('__________ reading___________',i)
    model = tf.keras.models.load_model(path_models+'\\'+ i,compile=False)
    print('model loaded')
    logslicesOver = np.array(model.predict(logslicesUnder, batch_size=8), dtype='float64')
    slicesOver = inverseLogScaleSlices(logslicesOver, slicesMax, slicesMin)
    slicesUnder=downSampleSlices(slices)
    print('metrics evaluation')
    ssims = np.mean(ssimMetric(logslices, logslicesOver))
    phasemetric = np.mean(ownPhaseMetric_numpy(logslices, logslicesOver))
    phasemetricCorrected = np.mean(ownPhaseMetricCorrected_numpy(logslices, logslicesOver))
    mse = np.mean((logslices - logslicesOver)**2)
    epoch_metrics = np.array((ssims,phasemetric,phasemetricCorrected,mse))
    metrics.append(epoch_metrics)
# Out:
# __________ reading___________ model_004096.h5
# c:\Users\diego\anaconda3\lib\site-packages\keras\initializers\initializers_v2.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# model loaded
# 16/16 [==============================] - 11s 621ms/step
# metrics evaluation
# __________ reading___________ model_008192.h5
# model loaded
# 16/16 [==============================] - 11s 659ms/step
# metrics evaluation
# __________ reading___________ model_012288.h5
# model loaded
# 16/16 [==============================] - 12s 717ms/step
# metrics evaluation
# __________ reading___________ model_016384.h5
# model loaded
# 16/16 [==============================] - 12s 708ms/step
# metrics evaluation
# __________ reading___________ model_020480.h5
# model loaded
# 16/16 [==============================] - 10s 587ms/step
# metrics evaluation
# __________ reading___________ model_024576.h5
# model loaded
# 16/16 [==============================] - 11s 646ms/step
# metrics evaluation
# __________ reading___________ model_028672.h5
# model loaded
# 16/16 [==============================] - 10s 574ms/step
# metrics evaluation
# __________ reading___________ model_032768.h5
# model loaded
# 16/16 [==============================] - 10s 574ms/step
# metrics evaluation
# __________ reading___________ model_036864.h5
# model loaded
# 16/16 [==============================] - 12s 720ms/step
# metrics evaluation
# __________ reading___________ model_040960.h5
# model loaded
# 16/16 [==============================] - 12s 718ms/step
# metrics evaluation
# __________ reading___________ model_045056.h5
# model loaded
# 16/16 [==============================] - 10s 586ms/step
# metrics evaluation
# __________ reading___________ model_049152.h5
# model loaded
# 16/16 [==============================] - 10s 620ms/step
# metrics evaluation
# __________ reading___________ model_053248.h5
# model loaded
# 16/16 [==============================] - 13s 745ms/step
# metrics evaluation
# __________ reading___________ model_057344.h5
# model loaded
# 16/16 [==============================] - 9s 554ms/step
# metrics evaluation
# __________ reading___________ model_061440.h5
# model loaded
# 16/16 [==============================] - 9s 560ms/step
# metrics evaluation
# __________ reading___________ model_065536.h5
# model loaded
# 16/16 [==============================] - 9s 548ms/step
# metrics evaluation
# __________ reading___________ model_069632.h5
# model loaded
# 16/16 [==============================] - 9s 535ms/step
# metrics evaluation
# __________ reading___________ model_073728.h5
# model loaded
# 16/16 [==============================] - 10s 581ms/step
# metrics evaluation
# __________ reading___________ model_077824.h5
# model loaded
# 16/16 [==============================] - 10s 588ms/step
# metrics evaluation
# __________ reading___________ model_081920.h5
# model loaded
# 16/16 [==============================] - 9s 568ms/step
# metrics evaluation
# __________ reading___________ model_086016.h5
# model loaded
# 16/16 [==============================] - 9s 573ms/step
# metrics evaluation
# __________ reading___________ model_090112.h5
# model loaded
# 16/16 [==============================] - 10s 587ms/step
# metrics evaluation
# __________ reading___________ model_094208.h5
# model loaded
# 16/16 [==============================] - 10s 589ms/step
# metrics evaluation
# __________ reading___________ model_098304.h5
# model loaded
# 16/16 [==============================] - 12s 684ms/step
# metrics evaluation
# __________ reading___________ model_102400.h5
# model loaded
# 16/16 [==============================] - 9s 549ms/step
# metrics evaluation
# __________ reading___________ model_106496.h5
# model loaded
# 16/16 [==============================] - 9s 554ms/step
# metrics evaluation
# __________ reading___________ model_110592.h5
# model loaded
# 16/16 [==============================] - 9s 549ms/step
# metrics evaluation
# __________ reading___________ model_114688.h5
# model loaded
# 16/16 [==============================] - 9s 555ms/step
# metrics evaluation
# __________ reading___________ model_118784.h5
# model loaded
# 16/16 [==============================] - 10s 589ms/step
# metrics evaluation
# __________ reading___________ model_122880.h5
# model loaded
# 16/16 [==============================] - 10s 593ms/step
# metrics evaluation
# __________ reading___________ model_126976.h5
# model loaded
# 16/16 [==============================] - 10s 598ms/step
# metrics evaluation
# __________ reading___________ model_131072.h5
# model loaded
# 16/16 [==============================] - 10s 589ms/step
# metrics evaluation
# __________ reading___________ model_135168.h5
# model loaded
# 16/16 [==============================] - 9s 530ms/step
# metrics evaluation
# __________ reading___________ model_139264.h5
# model loaded
# 16/16 [==============================] - 9s 570ms/step
# metrics evaluation
# __________ reading___________ model_143360.h5
# model loaded
# 16/16 [==============================] - 9s 569ms/step
# metrics evaluation
# __________ reading___________ model_147456.h5
# model loaded
# 16/16 [==============================] - 9s 551ms/step
# metrics evaluation
# __________ reading___________ model_151552.h5
# model loaded
# 16/16 [==============================] - 9s 551ms/step
# metrics evaluation
# __________ reading___________ model_155648.h5
# model loaded
# 16/16 [==============================] - 9s 534ms/step
# metrics evaluation
# __________ reading___________ model_159744.h5
# model loaded
# 16/16 [==============================] - 9s 545ms/step
# metrics evaluation
# __________ reading___________ model_163840.h5
# model loaded
# 16/16 [==============================] - 9s 550ms/step
# metrics evaluation
# __________ reading___________ model_167936.h5
# model loaded
# 16/16 [==============================] - 10s 594ms/step
# metrics evaluation
# __________ reading___________ model_172032.h5
# model loaded
# 16/16 [==============================] - 10s 595ms/step
# metrics evaluation
# __________ reading___________ model_176128.h5
# model loaded
# 16/16 [==============================] - 10s 583ms/step
# metrics evaluation
# __________ reading___________ model_180224.h5
# model loaded
# 16/16 [==============================] - 10s 600ms/step
# metrics evaluation
# __________ reading___________ model_184320.h5
# model loaded
# 16/16 [==============================] - 10s 612ms/step
# metrics evaluation
# __________ reading___________ model_188416.h5
# model loaded
# 16/16 [==============================] - 10s 591ms/step
# metrics evaluation
# __________ reading___________ model_192512.h5
# model loaded
# 16/16 [==============================] - 9s 555ms/step
# metrics evaluation
# __________ reading___________ model_196608.h5
# model loaded
# 16/16 [==============================] - 9s 553ms/step
# metrics evaluation
# __________ reading___________ model_200704.h5
# model loaded
# 16/16 [==============================] - 9s 555ms/step
# metrics evaluation
# __________ reading___________ model_204800.h5
# model loaded
# 16/16 [==============================] - 9s 560ms/step
# metrics evaluation
# __________ reading___________ model_208896.h5
# model loaded
# 16/16 [==============================] - 9s 553ms/step
# metrics evaluation
# __________ reading___________ model_212992.h5
# model loaded
# 16/16 [==============================] - 10s 586ms/step
# metrics evaluation
# __________ reading___________ model_217088.h5
# model loaded
# 16/16 [==============================] - 9s 568ms/step
# metrics evaluation
# __________ reading___________ model_221184.h5
# model loaded
# 16/16 [==============================] - 10s 573ms/step
# metrics evaluation
# __________ reading___________ model_225280.h5
# model loaded
# 16/16 [==============================] - 11s 659ms/step
# metrics evaluation
# __________ reading___________ model_229376.h5
# model loaded
# 16/16 [==============================] - 10s 582ms/step
# metrics evaluation
# __________ reading___________ model_233472.h5
# model loaded
# 16/16 [==============================] - 10s 577ms/step
# metrics evaluation
# __________ reading___________ model_237568.h5
# model loaded
# 16/16 [==============================] - 9s 552ms/step
# metrics evaluation
# __________ reading___________ model_241664.h5
# model loaded
# 16/16 [==============================] - 9s 558ms/step
# metrics evaluation
# __________ reading___________ model_245760.h5
# model loaded
# 16/16 [==============================] - 9s 547ms/step
# metrics evaluation
# __________ reading___________ model_249856.h5
# model loaded
# 16/16 [==============================] - 9s 540ms/step
# metrics evaluation
# __________ reading___________ model_253952.h5
# model loaded
# 16/16 [==============================] - 9s 555ms/step
# metrics evaluation
# __________ reading___________ model_258048.h5
# model loaded
# 16/16 [==============================] - 13s 811ms/step
# metrics evaluation
# __________ reading___________ model_262144.h5
# model loaded
# 16/16 [==============================] - 11s 652ms/step
# metrics evaluation
# __________ reading___________ model_266240.h5
# model loaded
# 16/16 [==============================] - 10s 603ms/step
# metrics evaluation
# __________ reading___________ model_270336.h5
# model loaded
# 16/16 [==============================] - 10s 601ms/step
# metrics evaluation
# __________ reading___________ model_274432.h5
# model loaded
# 16/16 [==============================] - 11s 695ms/step
# metrics evaluation
# __________ reading___________ model_278528.h5
# model loaded
# 16/16 [==============================] - 10s 596ms/step
# metrics evaluation
# __________ reading___________ model_282624.h5
# model loaded
# 16/16 [==============================] - 9s 567ms/step
# metrics evaluation
# __________ reading___________ model_286720.h5
# model loaded
# 16/16 [==============================] - 11s 641ms/step
# metrics evaluation
# __________ reading___________ model_290816.h5
# model loaded
# 16/16 [==============================] - 10s 590ms/step
# metrics evaluation
# __________ reading___________ model_294912.h5
# model loaded
# 16/16 [==============================] - 11s 635ms/step
# metrics evaluation
# __________ reading___________ model_299008.h5
# model loaded
# 16/16 [==============================] - 9s 548ms/step
# metrics evaluation
# __________ reading___________ model_303104.h5
# model loaded
# 16/16 [==============================] - 10s 608ms/step
# metrics evaluation
# __________ reading___________ model_307200.h5
# model loaded
# 16/16 [==============================] - 10s 584ms/step
# metrics evaluation
# __________ reading___________ model_311296.h5
# model loaded
# 16/16 [==============================] - 11s 662ms/step
# metrics evaluation
# __________ reading___________ model_315392.h5
# model loaded
# 16/16 [==============================] - 10s 624ms/step
# metrics evaluation
# __________ reading___________ model_319488.h5
# model loaded
# 16/16 [==============================] - 10s 598ms/step
# metrics evaluation
# __________ reading___________ model_323584.h5
# model loaded
# 16/16 [==============================] - 11s 672ms/step
# metrics evaluation
# __________ reading___________ model_327680.h5
# model loaded
# 16/16 [==============================] - 10s 582ms/step
# metrics evaluation
# __________ reading___________ model_331776.h5
# model loaded
# 16/16 [==============================] - 9s 528ms/step
# metrics evaluation
# __________ reading___________ model_335872.h5
# model loaded
# 16/16 [==============================] - 9s 551ms/step
# metrics evaluation
# __________ reading___________ model_339968.h5
# model loaded
# 16/16 [==============================] - 9s 534ms/step
# metrics evaluation
# __________ reading___________ model_344064.h5
# model loaded
# 16/16 [==============================] - 9s 530ms/step
# metrics evaluation
# __________ reading___________ model_348160.h5
# model loaded
# 16/16 [==============================] - 10s 613ms/step
# metrics evaluation
# __________ reading___________ model_352256.h5
# model loaded
# 16/16 [==============================] - 10s 580ms/step
# metrics evaluation
# __________ reading___________ model_356352.h5
# model loaded
# 16/16 [==============================] - 10s 574ms/step
# metrics evaluation
# __________ reading___________ model_360448.h5
# model loaded
# 16/16 [==============================] - 10s 629ms/step
# metrics evaluation
# __________ reading___________ model_364544.h5
# model loaded
# 16/16 [==============================] - 9s 561ms/step
# metrics evaluation
# __________ reading___________ model_368640.h5
# model loaded
# 16/16 [==============================] - 9s 560ms/step
# metrics evaluation
# __________ reading___________ model_372736.h5
# model loaded
# 16/16 [==============================] - 9s 517ms/step
# metrics evaluation
# __________ reading___________ model_376832.h5
# model loaded
# 16/16 [==============================] - 9s 557ms/step
# metrics evaluation
# __________ reading___________ model_380928.h5
# model loaded
# 16/16 [==============================] - 10s 619ms/step
# metrics evaluation
# __________ reading___________ model_385024.h5
# model loaded
# 16/16 [==============================] - 11s 609ms/step
# metrics evaluation
# __________ reading___________ model_389120.h5
# model loaded
# 16/16 [==============================] - 9s 553ms/step
# metrics evaluation
# __________ reading___________ model_393216.h5
# model loaded
# 16/16 [==============================] - 10s 590ms/step
# metrics evaluation
# __________ reading___________ model_397312.h5
# model loaded
# 16/16 [==============================] - 10s 630ms/step
# metrics evaluation
# __________ reading___________ model_401408.h5
# model loaded
# 16/16 [==============================] - 10s 587ms/step
# metrics evaluation
# __________ reading___________ model_405504.h5
# model loaded
# 16/16 [==============================] - 10s 586ms/step
# metrics evaluation
# __________ reading___________ model_409600.h5
# model loaded
# 16/16 [==============================] - 10s 600ms/step
# metrics evaluation

# %%
metrics_log = np.array(metrics)
np.save(path+'\\metrics_log',metrics_log)

# %%
ssims = metrics_log[:,0]
phasemetric = metrics_log[:,1]
phasemetricCorrected = metrics_log[:,2]
mse = metrics_log[:,3]
fig,axs = plt.subplots(2,2)
axs[0,0].plot(ssims)
axs[0,0].set_title('ssims')
axs[0,1].plot(mse)
axs[0,1].set_title('mse')
axs[1,0].plot(phasemetricCorrected)
axs[1,0].set_title('phase corrected')
axs[1,1].plot(phasemetric)
axs[1,1].set_title('phase')
# Out:
# Text(0.5, 1.0, 'phase')

# %%
def max_value(array):
    max_val = array[0]  # initialize maximum value as the first element of the array
    max_pos = 0         # initialize maximum position as 0
    for i in range(1, len(array)):
        if array[i] > max_val:
            max_val = array[i]  # update maximum value
            max_pos = i         # update maximum position
    return max_val, max_pos

def min_value(array):
    min_val = array[0]  # initialize maximum value as the first element of the array
    min_pos = 0         # initialize maximum position as 0
    for i in range(1, len(array)):
        if array[i] < min_val:
            min_val = array[i]  # update maximum value
            min_pos = i         # update maximum position
    return min_val, min_pos

max_val, max_pos = max_value(ssims)
print(f"The maximum value of the ssim metric is {max_val} and its position is {max_pos}.")

min_val, min_pos = min_value(ssims)
print(f"The minimum value of the ssim metric is {min_val} and its position is {min_pos}.")

max_val, max_pos = max_value(mse)
print(f"The maximum value of the mse metric is {max_val} and its position is {max_pos}.")

min_val, min_pos = min_value(mse)
print(f"The minimum value of the mse metric is {min_val} and its position is {min_pos}.")

max_val, max_pos = max_value(phasemetric)
print(f"The maximum value of the phase metric is {max_val} and its position is {max_pos}.")

min_val, min_pos = min_value(phasemetric)
print(f"The minimum value of the phase metric is {min_val} and its position is {min_pos}.")

max_val, max_pos = max_value(phasemetricCorrected)
print(f"The maximum value of the phase metric corrected is {max_val} and its position is {max_pos}.")

min_val, min_pos = min_value(phasemetricCorrected)
print(f"The minimum value of the phase metric corrected is {min_val} and its position is {min_pos}.")
# Out:
# The maximum value of the ssim metric is 0.6957074979071532 and its position is 2.
# The minimum value of the ssim metric is 0.671575500157753 and its position is 86.
# The maximum value of the mse metric is 0.03394579325835897 and its position is 43.
# The minimum value of the mse metric is 0.029100434762099437 and its position is 3.
# The maximum value of the phase metric is 0.2724712413831622 and its position is 53.
# The minimum value of the phase metric is 0.250815761977028 and its position is 3.
# The maximum value of the phase metric corrected is 1.675136070448863 and its position is 0.
# The minimum value of the phase metric corrected is 1.6062277561800298 and its position is 21.

# %%
max_ssim, max_pos_ssim = max_value(ssims)
min_mse, min_pos_mse = min_value(mse)
min_phase, min_pos_phase = min_value(phasemetric)
ssims[3]-ssims[2]
# Out:
# -0.00021278760568965716

# %%
n = 128
n1 = 128
window_size = (n,n)
stride = (n1,n1)
slices = []
zinit= int(np.round(tomShape[0][0]/2)-3)
zfinal= zinit + 6
for b in range(150):
    i = b
    bslicei = sliding_window(tomImag[i,:,:],window_size,stride)
    bslicer = sliding_window(tomReal[i,:,:],window_size,stride)
    bslice = np.stack((bslicer,bslicei),axis=3)
    slices.append(bslice)
slices = np.array(slices)
slices = np.reshape(slices,(slices.shape[0]*slices.shape[1],slices.shape[2],slices.shape[3],slices.shape[4]))
del bslicei,bslicer,bslice,tomImag,tomReal
logslices, slicesMax, slicesMin = logScaleSlices(slices)
logslicesUnder = downSampleSlices(logslices)
model = tf.keras.models.load_model(path_models+'\\'+ models[min_pos_mse],compile = False)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[54], line 17
#      15 slices = np.reshape(slices,(slices.shape[0]*slices.shape[1],slices.shape[2],slices.shape[3],slices.shape[4]))
#      16 del bslicei,bslicer,bslice,tomImag,tomReal
# ---> 17 logslices, slicesMax, slicesMin = logScaleSlices(slices)
#      18 logslicesUnder = downSampleSlices(logslices)
#      19 model = tf.keras.models.load_model(path_models+'\\'+ models[min_pos_mse],compile = False)
#
# File c:\Users\diego\OneDrive - Universidad EAFIT\Eafit\Trabajo de grado\OCT_Advanced_Postprocessing_copia\Analysis\DLOCT\cGAN_subsampling\Utils.py:79, in logScaleSlices(slices)
#      77 logslices = np.copy(slices)
#      78 nSlices = len(slices)
# ---> 79 logslicesAmp = abs(logslices[:, :, :, 0] + 1j*logslices[:, :, :, 1])
#      80 # and retrieve the phase
#      81 logslicesPhase = np.angle(logslices[:, :, :, 0] + 1j*logslices[:, :, :, 1])
#
# MemoryError: Unable to allocate 788. MiB for an array with shape (3150, 128, 128) and data type complex128

# %%
model = tf.keras.models.load_model(path_models+'\\'+ models[min_pos_mse],compile = False)
# Out:
# c:\Users\diego\anaconda3\lib\site-packages\keras\initializers\initializers_v2.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(

# %%
logslicesOver = np.array(model.predict(logslicesUnder, batch_size=8), dtype='float64')
slicesOver = inverseLogScaleSlices(logslicesOver, slicesMax, slicesMin)
# Out:
# 499/499 [==============================] - 331s 654ms/step

# %%
print('\n\n\t\t\t --- Quantitative metrics log scale ---\n')

ssims = np.mean(ssimMetric(logslices, logslicesOver))
phasemetric = np.mean(ownPhaseMetric_numpy(logslices, logslicesOver))
phasemetricCorrected = np.mean(ownPhaseMetricCorrected_numpy(logslices, logslicesOver))
mse = np.mean((logslices - logslicesOver)**2)

print('\t\t -- For test data')
print('MSE: ', mse)
print('Phase STD [0, 1]: ', phasemetric)
print('Phase STD [-1, 1]: ', phasemetricCorrected)
print('SSIM: ', ssims)
# Out:
# 			 --- Quantitative metrics log scale ---
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[53], line 3
#       1 print('\n\n\t\t\t --- Quantitative metrics log scale ---\n')
# ----> 3 ssims = np.mean(ssimMetric(logslices, logslicesOver))
#       4 phasemetric = np.mean(ownPhaseMetric_numpy(logslices, logslicesOver))
#       5 phasemetricCorrected = np.mean(ownPhaseMetricCorrected_numpy(logslices, logslicesOver))
#
# File c:\Users\diego\OneDrive - Universidad EAFIT\Eafit\Trabajo de grado\OCT_Advanced_Postprocessing_copia\Analysis\DLOCT\cGAN_subsampling\Metrics.py:90, in ssimMetric(slices, slicesOver)
#      88 def ssimMetric(slices, slicesOver): # that is (y_true, y_predicted)
#      89     slicesInt = slices[:, :, :, 0]**2 + slices[:, :, :, 1]**2
# ---> 90     slicesOverInt = slicesOver[:, :, :, 0]**2 + slicesOver[:, :, :, 1]**2
#      91     ssims = []
#      92     for i in range(len(slicesInt)):
#
# MemoryError: Unable to allocate 499. MiB for an array with shape (3990, 128, 128) and data type float64
